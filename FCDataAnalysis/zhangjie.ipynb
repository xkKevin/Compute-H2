# %%
from FCAnalysis import *

# %%
import pyedflib
from mpl_toolkits.mplot3d  import Axes3D

# %%
f = pyedflib.EdfReader(r"D:\data\FCDataAnalysis\zhangjie-10sz.edf")
n = f.signals_in_file
signal_labels = f.getSignalLabels()
record = np.zeros((n, f.getNSamples()[0]))
for i in np.arange(n):
    record[i, :] = f.readSignal(i)

# %%
sampleFreq = f.getSampleFrequency(1)
signalSam = f.getNSamples()[1]
sigDur = f.getFileDuration()
sampleFreq,signalSam,sigDur,signalSam/sigDur
# Out:
# (999, 699006, 699, 1000.0085836909872)

# %%
sampleFreq = 100

# %%
#10-401（发作间期），429（起始点）,439（关注点）,475（结束点）
# SOZ  13-18
c13 = [3.962499, 0.178310, 1.812862]
c14 = [4.100949, 0.572580, 1.995454]
c15 = [4.198444, 0.867324, 2.081577]
c16 = [4.302242, 1.182725, 2.166495]
c17 = [4.331316, 1.475512, 2.276254]
c18 = [4.436385, 1.770917, 2.359782]

# PP  1-12，55，74-88
c2 = [4.204174, 3.372997, 5.165071]
c3 = [4.268334, 3.681691, 5.157468]

c5 = [4.322492, 4.387421, 5.172174]
c6 = [4.292322, 4.682370, 5.196633]

c7 = [4.368369, 5.091016, 5.189650]
c8 = [4.346697, 5.392070, 5.211452]
c9 = [4.413306, 5.795728, 5.207505]

c10 = [4.400343, 6.199419, 5.231157]
c11 = [4.440647, 6.577568, 5.235123]
c12 = [4.460672, 6.926661, 5.244743]

c75 = [2.619082, 3.588806, 3.714572]
c76 = [2.617952, 3.642142, 4.095845]

c80 = [2.623602, 3.729245, 5.495568]
c81 = [2.625014, 3.751021, 5.845498]

c86 = [2.634762, 3.822944, 7.534534]
c87 = [2.620340, 3.878273, 7.857322]

# NIZ  33-38，100-103，111-114
c33 = [7.535974, 1.638909, 4.245139]
c34 = [7.523327, 1.944420, 4.264022]

c37 = [7.480632, 3.026897, 4.436144]
c38 = [7.457274, 3.334506, 4.458841]

c101 = [1.219850, 5.767434, 2.711399]
c102 = [1.246356, 6.160532, 2.826809]

c111 = [3.435985, -5.658635, 4.367223]
c112 = [3.557152, -5.860629, 4.421566]
c113 = [3.654113, -6.657856, 4.463095]
c114 = [3.714259, -7.001917, 4.485552]

# %%
#10-401（发作间期），429（起始点）,439（关注点）,475（结束点）
# SOZ  13-18
c13_14 = points_center(c13,c14)
c14_15 = points_center(c14,c15)
c15_16 = points_center(c15,c16)
c16_17 = points_center(c16,c17)
c17_18 = points_center(c17,c18)

ez_c = np.array([c13_14,c14_15,c15_16,c16_17,c17_18])
# PP  1-12，55，74-88
c2_3 = points_center(c2,c3)
#c5_6 = points_center(c5,c6)
c6_7 = points_center(c6,c7)
#c7_8 = points_center(c7,c8)
#c8_9 = points_center(c8,c9)
c10_11 = points_center(c10,c11)

c75_76 = points_center(c75,c76)
c80_81 = points_center(c80,c81)
c86_87 = points_center(c86,c87)

pz_c = np.array([c2_3,c6_7,c10_11,c75_76,c80_81,c86_87])
# NIZ  33-38，100-103，111-114
c33_34 = points_center(c33,c34)
c37_38 = points_center(c37,c38)

c101_102 = points_center(c101,c102)

c111_112 = points_center(c111,c112)
c113_114 = points_center(c113,c114)

niz_c = np.array([c33_34,c37_38,c101_102,c111_112,c113_114])

# %%
#10-401（发作间期），429（起始点）,439（关注点）,475（结束点）
# SOZ  13-18
s13_14 = record[13]-record[14]
s14_15 = record[14]-record[15]
s15_16 = record[15]-record[16]
s16_17 = record[16]-record[17]
s17_18 = record[17]-record[18]

ez_s = np.array([s13_14,s14_15,s15_16,s16_17,s17_18])
# PP  1-12，55，74-88
s2_3 = record[2]-record[3]
s6_7 = record[6]-record[7]
#c7_8 = points_center(c7,c8)
#c8_9 = points_center(c8,c9)
s10_11 = record[10]-record[11]

s75_76 = record[75]-record[76]
s80_81 = record[80]-record[81]
s86_87 = record[86]-record[87]

pz_s = np.array([s2_3,s6_7,s10_11,s75_76,s80_81,s86_87])
# NIZ  33-38，100-103，111-114
s33_34 = record[33]-record[34]
s37_38 = record[37]-record[38]

s101_102 = record[101]-record[102]

s111_112 = record[111]-record[112]
s113_114 = record[113]-record[114]

niz_s = np.array([s33_34,s37_38,s101_102,s111_112,s113_114])

# %%
ez = h2_in_suit(ez_s,ez_c,'EZ内部',429,48,sampleFreq,slideWindow=2,maxlag=0.001)

# %%
ez[3]
# Out:
# 0.1415238953578878

# %%
pz = h2_in_suit(pz_s,pz_c,'PZ内部',429,48,sampleFreq,slideWindow=2,maxlag=0.001)

# %%
pz[3]
# Out:
# 0.16517444838017648

# %%
niz = h2_in_suit(niz_s,niz_c,'NIZ内部',429,48,sampleFreq,slideWindow=2,maxlag=0.001)

# %%
niz[3]
# Out:
# 0.06386465134510635

# %%
ez_pz = h2_btw_suit(ez_s[::2],pz_s[::2],ez_c[::2],pz_c[::2],'EZ与PZ',429,48,sampleFreq,maxlag=0.001)

# %%
ez_pz[3]
# Out:
# 0.1570936349801969

# %%
ez_niz = h2_btw_suit(ez_s[::2],niz_s[::2],ez_c[::2],niz_c[::2],'EZ与NIZ',429,48,sampleFreq,maxlag=0.001)

# %%
ez_niz[3]
# Out:
# 0.20466691145865745

# %%
pz_niz = h2_btw_suit(pz_s[::2],niz_s[::2],pz_c[::2],niz_c[::2],'PZ与NIZ',429,48,sampleFreq,maxlag=0.001)

# %%
pz_niz[3]
# Out:
# 0.14076995931016023

# %%
#ez_all = np.ravel(ez[1])
ez_all = np.ravel([i[0] for i in ez[1]])
pz_all = np.ravel([i[0] for i in pz[1]])
niz_all = np.ravel([i[0] for i in niz[1]])
ez_pz_all = np.ravel([i[0] for i in ez_pz[1]])
ez_niz_all = np.ravel([i[0] for i in ez_niz[1]])
pz_niz_all = np.ravel([i[0] for i in pz_niz[1]])

# %%
len(ez_all),len(ez[1]),len(ez[1][0]),len(ez[1][0][0])
# Out:
# (460, 10, 2, 46)

# %%
def violinbox(vlist,title):
    plt.figure(figsize=(12,7))
    vp = plt.violinplot(vlist,showmedians=True) # data里是元素（如data1）还不允许是Series
    color=['DeepSkyBlue','MediumSpringGreen','Yellow','Orange','Violet','BlueViolet']
    i=0
    for pc in vp['bodies']:
        pc.set_facecolor(color[i])
        pc.set_edgecolor('black')
        i+=1
    plt.boxplot(vlist,widths=0.02,patch_artist=True,boxprops={'color':'k','facecolor':'k'},showcaps=False,\
                 showmeans=True,meanprops={'markerfacecolor':'r'},showfliers=False,medianprops={'color':'k'})
    for i in range(0,6):
        median = np.median(vlist[i])
        plt.text(i+1,np.max(vlist[i])+0.006,np.round(median,3),ha='center',va='bottom',fontsize=15)
    #ax=plt.gca()
    #ax.spines['bottom'].set_position(('data',0)) 
    plt.ylim(0,1)
    plt.title(title,fontsize=18)
    plt.grid()
    plt.xticks(list(range(1,7)),['EZ','PZ','NIZ','EZ-PZ','EZ-NIZ','PZ-NIZ'])  # 只能这么设置label

    
def line(llist,label,title,start,step):
    plt.figure(figsize=(17,5))
    x = list(range(start,step*len(llist[0])+start,step))
    for i in range(len(llist)):
        plt.plot(x,llist[i],label=label[i])
    #plt.xticks(np.linspace(0,ll-1,pd),np.linspace(start,start+ll-1,pd,dtype=int))
    plt.legend()
    plt.title(title,fontsize=18)
    plt.grid()
    plt.show()
    
def h2_in_suit(zone,cod,label,start_time,duration,sampleFreq,slideWindow=2,step=1,maxlag=0.1,L=7,HP=0,LP=0):
    h2_bwt=[]
    h2_bwt_max=[]
    h2_bwt_median=[]
    h2_per_max = []
    codistance = []
    lz = len(zone)
    for i in range(lz-1):
        for j in range(i+1,lz):
            h2_bwt.append(H2_filter([zone[i],zone[j]],start_time,duration,sampleFreq,slideWindow,step,maxlag,L,HP,LP))
            h2_bwt_max.append(H2_max(h2_bwt[-1][0],h2_bwt[-1][1]))
            a,b=np.percentile(h2_bwt_max[-1][0],[50,100])
            h2_bwt_median.append(a)
            h2_per_max.append(b)
            codistance.append(points_dist(cod[i],cod[j]))
    line([i[0] for i in h2_bwt_max],np.round(codistance,3),label+' FC随时间变化的折线图',start_time,step)
    violin([i[0] for i in h2_bwt_max],np.round(codistance,3),label+' FC小提琴图')
    for i in range(len(h2_bwt_median)):
        plt.text(i+1,h2_per_max[i]+0.01,np.round(h2_bwt_median[i],3),ha='center',va='bottom',fontsize=15) # ha：水平对齐，va：垂直对齐
    return h2_bwt,h2_bwt_max,h2_bwt_median,np.median(h2_bwt_median),codistance


def h2_btw_suit(zone1,zone2,cod1,cod2,label,start_time,duration,sampleFreq,slideWindow=2,step=1,maxlag=0.1,L=7,HP=0,LP=0):
    h2_bwt=[]
    h2_bwt_max=[]
    h2_bwt_median=[]
    h2_per_max = []
    codistance = []
    lz2 = len(zone2)
    for i in range(len(zone1)):
        for j in range(lz2):
            h2_bwt.append(H2_filter([zone1[i],zone2[j]],start_time,duration,sampleFreq,slideWindow,step,maxlag,L,HP,LP))
            h2_bwt_max.append(H2_max(h2_bwt[-1][0],h2_bwt[-1][1]))
            a,b=np.percentile(h2_bwt_max[-1][0],[50,100])
            h2_bwt_median.append(a)
            h2_per_max.append(b)
            codistance.append(points_dist(cod1[i],cod2[j]))
    line([i[0] for i in h2_bwt_max],np.round(codistance,3),label+' FC随时间变化的折线图',start_time,step)
    violin([i[0] for i in h2_bwt_max],np.round(codistance,3),label+' FC小提琴图')
    for i in range(len(h2_bwt_median)):
        plt.text(i+1,h2_per_max[i]+0.01,np.round(h2_bwt_median[i],3),ha='center',va='bottom',fontsize=15) # ha：水平对齐，va：垂直对齐
    return h2_bwt,h2_bwt_max,h2_bwt_median,np.median(h2_bwt_median),codistance

# %%
violinbox([ez_all,pz_all,niz_all,ez_pz_all,ez_niz_all,pz_niz_all],'癫痫发作时期FC小提琴图')

# %%
ezi = h2_in_suit(ez_s,ez_c,'EZ内部',100,209,sampleFreq,slideWindow=8,step=4,maxlag=0.001)

# %%
ezi[3]
# Out:
# 0.1775333482936195

# %%
pzi = h2_in_suit(pz_s,pz_c,'PZ内部',100,209,sampleFreq,slideWindow=8,step=4,maxlag=0.001)

# %%
pzi[3]
# Out:
# 0.08935288558340371

# %%
nizi = h2_in_suit(niz_s,niz_c,'NIZ内部',100,209,sampleFreq,slideWindow=8,step=4,maxlag=0.001)

# %%
nizi[3]
# Out:
# 0.03689265515187801

# %%
ez_pzi = h2_btw_suit(ez_s[::2],pz_s[::2],ez_c[::2],pz_c[::2],'EZ与PZ',100,209,sampleFreq,slideWindow=8,step=4,maxlag=0.001)

# %%
ez_pzi[3]
# Out:
# 0.06806270455171304

# %%
ez_nizi = h2_btw_suit(ez_s[::2],niz_s[::2],ez_c[::2],niz_c[::2],'EZ与NIZ',100,209,sampleFreq,slideWindow=8,step=4,maxlag=0.001)

# %%
ez_nizi[3]
# Out:
# 0.1160346601253126

# %%
pz_nizi = h2_btw_suit(pz_s[::2],niz_s[::2],pz_c[::2],niz_c[::2],'PZ与NIZ',100,209,sampleFreq,slideWindow=8,step=4,maxlag=0.001)

# %%
pz_nizi[3]
# Out:
# 0.05242528004303393

# %%
ezi_all = np.ravel([i[0] for i in ezi[1]])
pzi_all = np.ravel([i[0] for i in pzi[1]])
nizi_all = np.ravel([i[0] for i in nizi[1]])
ez_pzi_all = np.ravel([i[0] for i in ez_pzi[1]])
ez_nizi_all = np.ravel([i[0] for i in ez_nizi[1]])
pz_nizi_all = np.ravel([i[0] for i in pz_nizi[1]])

# %%
violinbox([ezi_all,pzi_all,nizi_all,ez_pzi_all,ez_nizi_all,pz_nizi_all],'癫痫发作间期FC小提琴图')
